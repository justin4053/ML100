# %% [markdown]
# ## 練習時間
# 資料的操作有很多，接下來的馬拉松中我們會介紹常被使用到的操作，參加者不妨先自行想像一下，第一次看到資料，我們一般會想知道什麼訊息？
#
# #### Ex: 如何知道資料的 row 數以及 column 數、有什麼欄位、多少欄位、如何截取部分的資料等等
#
# 有了對資料的好奇之後，我們又怎麼通過程式碼來達成我們的目的呢？
#
# #### 可參考該[基礎教材](https://bookdata.readthedocs.io/en/latest/base/01_pandas.html#DataFrame-%E5%85%A5%E9%97%A8)或自行 google

# %%
import os
import numpy as np
import pandas as pd

# %%
# 設定 data_path
dir_data = 'C:\\Users\\justi\\Desktop\\ML100\\kaggle\\Home Credit Default Risk'

# %%
f_app = os.path.join(dir_data, 'application_train.csv')
print('Path of read in data: %s' % f_app)
app_train = pd.read_csv(f_app)
# Out:
# Path of read in data: C:\Users\justi\Desktop\ML100\kaggle\Home Credit Default Risk\application_train.csv

# %% [markdown]
# ### 如果沒有想法，可以先嘗試找出剛剛例子中提到的問題的答案
# #### 資料的 row 數以及 column 數

# %%
app_train.shape
app_train.describe()
# Out:
#           SK_ID_CURR         TARGET   CNT_CHILDREN  AMT_INCOME_TOTAL  \
# count  307511.000000  307511.000000  307511.000000      3.075110e+05
# mean   278180.518577       0.080729       0.417052      1.687979e+05
# std    102790.175348       0.272419       0.722121      2.371231e+05
# min    100002.000000       0.000000       0.000000      2.565000e+04
# 25%    189145.500000       0.000000       0.000000      1.125000e+05
# 50%    278202.000000       0.000000       0.000000      1.471500e+05
# 75%    367142.500000       0.000000       1.000000      2.025000e+05
# max    456255.000000       1.000000      19.000000      1.170000e+08
#
#          AMT_CREDIT    AMT_ANNUITY  AMT_GOODS_PRICE  \
# count  3.075110e+05  307499.000000     3.072330e+05
# mean   5.990260e+05   27108.573909     5.383962e+05
# std    4.024908e+05   14493.737315     3.694465e+05
# min    4.500000e+04    1615.500000     4.050000e+04
# 25%    2.700000e+05   16524.000000     2.385000e+05
# ...

# %% [markdown]
# #### 列出所有欄位

# %%
app_train.columns
# Out:
# Index(['SK_ID_CURR', 'TARGET', 'NAME_CONTRACT_TYPE', 'CODE_GENDER',
#        'FLAG_OWN_CAR', 'FLAG_OWN_REALTY', 'CNT_CHILDREN', 'AMT_INCOME_TOTAL',
#        'AMT_CREDIT', 'AMT_ANNUITY',
#        ...
#        'FLAG_DOCUMENT_18', 'FLAG_DOCUMENT_19', 'FLAG_DOCUMENT_20',
#        'FLAG_DOCUMENT_21', 'AMT_REQ_CREDIT_BUREAU_HOUR',
#        'AMT_REQ_CREDIT_BUREAU_DAY', 'AMT_REQ_CREDIT_BUREAU_WEEK',
#        'AMT_REQ_CREDIT_BUREAU_MON', 'AMT_REQ_CREDIT_BUREAU_QRT',
#        'AMT_REQ_CREDIT_BUREAU_YEAR'],
#       dtype='object', length=122)

# %% [markdown]
# #### 截取部分資料

# %%
app_train.head()
# Out:
#    SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 0      100002       1         Cash loans           M            N
# 1      100003       0         Cash loans           F            N
# 2      100004       0    Revolving loans           M            Y
# 3      100006       0         Cash loans           F            N
# 4      100007       0         Cash loans           M            N
#
#   FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 0               Y             0          202500.0    406597.5      24700.5
# 1               N             0          270000.0   1293502.5      35698.5
# 2               Y             0           67500.0    135000.0       6750.0
# 3               Y             0          135000.0    312682.5      29686.5
# 4               Y             0          121500.0    513000.0      21865.5
#
#               ...              FLAG_DOCUMENT_18 FLAG_DOCUMENT_19  \
# ...

# %% [markdown]
# #### 還有各種數之不盡的資料操作，重點還是取決於實務中遇到的狀況和你想問的問題，在馬拉松中我們也會陸續提到更多例子

# %%
app_train[app_train['NAME_CONTRACT_TYPE'] == 'Revolving loans']
# Out:
#         SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 2           100004       0    Revolving loans           M            Y
# 9           100012       0    Revolving loans           M            N
# 17          100021       0    Revolving loans           F            N
# 18          100022       0    Revolving loans           F            N
# 20          100024       0    Revolving loans           M            Y
# 29          100034       0    Revolving loans           M            N
# 39          100046       0    Revolving loans           M            Y
# 45          100052       0    Revolving loans           F            N
# 50          100058       0    Revolving loans           F            N
# 57          100068       0    Revolving loans           M            N
# 67          100079       0    Revolving loans           M            N
# 68          100080       0    Revolving loans           F            N
# ...

# %%
app_train[(app_train['NAME_CONTRACT_TYPE'] == 'Revolving loans') & (app_train["TARGET"] == 1) & (app_train['CODE_GENDER'] =='M') & (app_train['CNT_CHILDREN'] == 3)]
# Out:
#         SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 180         100209       1    Revolving loans           M            N
# 6365        107428       1    Revolving loans           M            N
# 24527       128533       1    Revolving loans           M            N
# 57930       167146       1    Revolving loans           M            Y
# 154525      279099       1    Revolving loans           M            Y
# 181571      310449       1    Revolving loans           M            Y
# 214658      348736       1    Revolving loans           M            N
# 259740      400583       1    Revolving loans           M            Y
#
#        FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  \
# 180                  Y             3          180000.0    540000.0
# 6365                 N             3          180000.0    180000.0
# 24527                Y             3           72000.0    180000.0
# ...

# %%
app_train[['SK_ID_CURR','TARGET']]
# Out:
#         SK_ID_CURR  TARGET
# 0           100002       1
# 1           100003       0
# 2           100004       0
# 3           100006       0
# 4           100007       0
# 5           100008       0
# 6           100009       0
# 7           100010       0
# 8           100011       0
# 9           100012       0
# 10          100014       0
# 11          100015       0
# 12          100016       0
# 13          100017       0
# 14          100018       0
# 15          100019       0
# 16          100020       0
# 17          100021       0
# 18          100022       0
# 19          100023       0
# 20          100024       0
# 21          100025       0
# 22          100026       0
# 23          100027       0
# 24          100029       0
# 25          100030       0
# 26          100031       1
# 27          100032       0
# 28          100033       0
# 29          100034       0
# ...            ...     ...
# 307481      456225       1
# 307482      456226       0
# ...
